# %% [markdown]
# # Area Charts Using Plotly Graph Objects (go)

# %% [markdown]
# ## List Data

# %%
import plotly.graph_objects as go
go.Figure(data=go.Scatter(x=[1, 2, 3, 4], y=[0, 2, 3, 5], fill='tozeroy'))

# %% [markdown]
# ## Hide Line

# %%
import plotly.graph_objects as go
go.Figure(data=go.Scatter(x=[1, 2, 3, 4], y=[0, 2, 3, 5], fill='tozeroy', mode='none'))

# %% [markdown]
# ## Line Style

# %%
import plotly.graph_objects as go
go.Figure(data=go.Scatter(
    x    = [1, 2, 3, 4], 
    y    = [0, 2, 3, 5], 
    fill = 'tozeroy', 
    line = {"width":3.5, "color":'rgb(111, 231, 219)'}
))

# %% [markdown]
# ## Multiple Area

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[0, 2, 3, 5], fill='tozeroy'))
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[3, 5, 1, 7], fill='tozeroy'))

# %% [markdown]
# ## Stacked Area

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[0, 2, 3, 5], fill='tozeroy')) 
fig.add_trace(go.Scatter(x=[1, 2, 3, 4], y=[3, 5, 1, 7], fill='tonexty')) # y is cumulative sum

# %% [markdown]
# ## Area Between Traces

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(
    x          = [1, 2, 3, 4], 
    y          = [3, 4, 8, 3],
    fill       = None,
    mode       = 'lines',
    line_color = 'indigo',
))

fig.add_trace(go.Scatter(
    x          = [1, 2, 3, 4], 
    y          = [1, 6, 2, 6],
    fill       = 'tonexty',
    mode       = 'lines', 
    line_color = 'indigo'
))

# %% [markdown]
# ## Stacked Area

# %%
import plotly.graph_objects as go

x = ['Winter', 'Spring', 'Summer', 'Fall']

fig = go.Figure()

fig.add_trace(go.Scatter(
    x          = x, 
    y          = [40, 60, 40, 10],
    hoverinfo  = 'x+y',
    mode       = 'lines',
    line       = {"width":0.5, "color":'rgb(131, 90, 241)'},
    stackgroup = 'one' # define stack group
))

fig.add_trace(go.Scatter(
    x          = x, 
    y          = [20, 10, 10, 60],
    hoverinfo  = 'x+y',
    mode       = 'lines',
    line       = {"width":0.5, "color":'rgb(111, 231, 219)'},
    stackgroup = 'one'
))

fig.add_trace(go.Scatter(
    x          = x, 
    y          = [40, 30, 50, 30],
    hoverinfo  = 'x+y',
    mode       = 'lines',
    line       = {"width":0.5, "color":'rgb(184, 247, 212)'},
    stackgroup = 'one'
))

fig.update_layout(
  showlegend  = True,
  xaxis_type  = 'category',
  yaxis       = {
    "type"      : 'linear',
    "range"     : [1, 100],
    "ticksuffix":'%'
    }
)
