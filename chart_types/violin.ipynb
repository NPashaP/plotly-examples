# %% [markdown]
# # Violin Chart With Express

# %%
import plotly.express as px
px.violin(px.data.tips(), y="tip", x="smoker", color="sex")

# %%
import plotly.express as px
px.violin(px.data.tips(), y="tip", x="smoker", color="sex", box=True)

# %%
import plotly.express as px
px.violin(px.data.tips(), y="tip", x="smoker", color="sex", points="all")
