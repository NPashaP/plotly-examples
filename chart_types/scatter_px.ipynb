# %% [markdown]
# # Scatter Plot Using Plotly Express

# %% [markdown]
# ## From Lists

# %%
import plotly.express as px
px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])

# %% [markdown]
# ## Setting Width and Height

# %%
import plotly.express as px
px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16], width=800, height=800)

# %% [markdown]
# ## From DataFrame

# %%
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length")

# %% [markdown]
# ## Title and Labels

# %%
# Set symbol using symbol paramter
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", 
  labels={"sepal_length":"Sepal Length", "sepal_width":"Sepal Width"},
  title="Iris"  
)

# %% [markdown]
# ## Categorical Color

# %%
# Color using color parameter. If column is categorical, then discrete color is used
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species")

# %% [markdown]
# ## Continuous Color

# %%
# if color column is numeric, then a continuous color scale is used
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color='petal_length')

# %% [markdown]
# ## Size of Points

# %%
# Set size using size paramter
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species", size='petal_length')

# %% [markdown]
# ## Symbol

# %%
# Set symbol using symbol paramter
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species", symbol="species")

# %% [markdown]
# ## Tooltip Data

# %%
# Add additional columns from DF to be shown on hover using hover_data
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species",
                 size='petal_length', hover_data=['petal_width'])

# %% [markdown]
# ## Categorical Axis

# %%
# The axes could be categorical
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="species")

# %% [markdown]
# ## Marginal Histogram

# %%
# Adding marginal histogram
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_length", y="sepal_width", marginal_x="histogram")

# %% [markdown]
# ## Marginal Rug

# %%
# Adding marginal rug
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_length", y="sepal_width", marginal_x="rug")

# %% [markdown]
# ## Marginal Box

# %%
# Adding marginal rug
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_length", y="sepal_width", marginal_y="box")

# %% [markdown]
# ## Marginal Violin

# %%
# Adding marginal rug
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_length", y="sepal_width", marginal_y="violin")

# %% [markdown]
# ## Trendline: Ordinary Least Square (OLS)

# %%
import plotly.express as px
px.scatter(px.data.iris(), x="sepal_width", y="sepal_length", color="species", trendline="ols")

# %% [markdown]
# ## Overall Trendline

# %%
import plotly.express as px
px.scatter(px.data.tips(), x="total_bill", y="tip", trendline="ols", color="sex", trendline_scope="overall")

# %% [markdown]
# ## Trendline: Log

# %%
# Log transformed trendline
import plotly.express as px
px.scatter(px.data.gapminder(year=2007), x="gdpPercap", y="lifeExp", 
                 trendline="ols", trendline_options={"log_x":True})

# %% [markdown]
# ## Trendline: Locally Weighted Scatterplot Smoothing (LOWESS)

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="lowess", trendline_options={"frac":0.1})

# %% [markdown]
# ## Trendline: Moving Average

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="rolling", trendline_options={"window":5})

# %% [markdown]
# ## Trendline: Moving Median

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="rolling", trendline_options={"function":"median","window":5})

# %% [markdown]
# ## Trendline: Exponentially Weighted Moving Average

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="ewm", trendline_options={"halflife":2})

# %% [markdown]
# ## Trendline: Expanding Mean

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="expanding")

# %% [markdown]
# ## Trendline: Expanding Max

# %%
import plotly.express as px
px.scatter(px.data.stocks(datetimes=True), x="date", y="GOOG", trendline="expanding", trendline_options={"function":"max"})

# %% [markdown]
# # Displaying Only Trendlines

# %%
import plotly.express as px

fig = px.scatter(px.data.stocks(indexed=True, datetimes=True), trendline="rolling", trendline_options=dict(window=5),
                title="5-point moving average")
fig.data = [t for t in fig.data if t.mode == "lines"]
fig.update_traces(showlegend=True) #trendlines have showlegend=False by default
fig

# %% [markdown]
# ## Error Bars

# %%
import plotly.express as px
df = px.data.iris()
df["e_x"] = df["sepal_width"]/100
df["e_y"] = df["sepal_width"]/150
px.scatter(df, x="sepal_width", y="sepal_length", color="species", error_x="e_x", error_y="e_y")

# %% [markdown]
# ## Custom Line

# %%
# Add a line
import plotly.express as px
import plotly.graph_objects as go 

df = px.data.iris()

fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")

fig.add_trace(
    go.Scatter(
        x=[2, 4],
        y=[4, 8],
        mode="lines",
        line=go.scatter.Line(color="gray"),
        showlegend=False)
)
fig.show()

# %% [markdown]
# ## Logarithmic Axis

# %%
# Logarithmic axes
import plotly.express as px
px.scatter(px.data.gapminder().query("year==2007"), x="gdpPercap", y="lifeExp", size="pop", color="continent", log_x=True)

# %% [markdown]
# ## Maximum Size

# %%
# Set a max size
import plotly.express as px
px.scatter(px.data.gapminder().query("year==2007"), x="gdpPercap", y="lifeExp", size="pop", color="continent",
            log_x=True, size_max=60)

# %% [markdown]
# ## Facets (Matrix)

# %%
import plotly.express as px
px.scatter(px.data.tips(), x="total_bill", y="tip", color="smoker", facet_col="sex", facet_row="time", width=600, height=600)

# %% [markdown]
# ## Facets With Trendline

# %%
import plotly.express as px
px.scatter(px.data.tips(), x="total_bill", y="tip", color="smoker", facet_col="sex", facet_row="time",
    trendline="ols", trendline_scope="overall", trendline_color_override="black", width=700, height=600)

# %% [markdown]
# ## Facets With Custom Line

# %%
import plotly.express as px
import plotly.graph_objects as go 

df = px.data.iris()

fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", facet_col="species",
                 title="Adding Traces To Subplots Witin A Plotly Express Figure", width=1200)

reference_line = go.Scatter(x=[2, 4],
                            y=[4, 8],
                            mode="lines",
                            line=go.scatter.Line(color="gray"),
                            showlegend=False)

fig.add_trace(reference_line, row=1, col=1)
fig.add_trace(reference_line, row=1, col=2)
fig.add_trace(reference_line, row=1, col=3)

fig.show()

# %% [markdown]
# ## Point Label

# %%
import plotly.express as px

df = px.data.gapminder().query("year==2007 and continent=='Americas'")

fig = px.scatter(df, x="gdpPercap", y="lifeExp", text="country", log_x=True, size_max=60, 
   height=800, width=1200, title="GDP and Life Expectancy (Americas, 2007)")

fig.update_traces(textposition='top center')
fig

# %% [markdown]
# ## Animation

# %%
import plotly.express as px
px.scatter(px.data.gapminder(), x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country", facet_col="continent",
           log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90])

# %% [markdown]
# ## Simple actual vs predicted plot

# %%
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression

df = px.data.iris()
X = df[['sepal_width', 'sepal_length']]
y = df['petal_width']

# Condition the model on sepal width and length, predict the petal width
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

fig = px.scatter(x=y, y=y_pred, labels={'x': 'ground truth', 'y': 'prediction'})
fig.add_shape(
    type="line", line=dict(dash='dash'),
    x0=y.min(), y0=y.min(),
    x1=y.max(), y1=y.max()
)
fig.show()

# %% [markdown]
# ## Enhanced prediction error analysis

# %%
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = px.data.iris()

# Split data into training and test splits
train_idx, test_idx = train_test_split(df.index, test_size=.25, random_state=0)
df['split'] = 'train'
df.loc[test_idx, 'split'] = 'test'

X = df[['sepal_width', 'sepal_length']]
y = df['petal_width']
X_train = df.loc[train_idx, ['sepal_width', 'sepal_length']]
y_train = df.loc[train_idx, 'petal_width']

# Condition the model on sepal width and length, predict the petal width
model = LinearRegression()
model.fit(X_train, y_train)
df['prediction'] = model.predict(X)

fig = px.scatter(
    df, x='petal_width', y='prediction',
    marginal_x='histogram', marginal_y='histogram',
    color='split', trendline='ols'
)
fig.update_traces(histnorm='probability', selector={'type':'histogram'})
fig.add_shape(
    type="line", line=dict(dash='dash'),
    x0=y.min(), y0=y.min(),
    x1=y.max(), y1=y.max()
)

fig.show()

# %% [markdown]
# ## Residual plots

# %%
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = px.data.iris()

# Split data into training and test splits
train_idx, test_idx = train_test_split(df.index, test_size=.25, random_state=0)
df['split'] = 'train'
df.loc[test_idx, 'split'] = 'test'

X = df[['sepal_width', 'sepal_length']]
X_train = df.loc[train_idx, ['sepal_width', 'sepal_length']]
y_train = df.loc[train_idx, 'petal_width']

# Condition the model on sepal width and length, predict the petal width
model = LinearRegression()
model.fit(X_train, y_train)
df['prediction'] = model.predict(X)
df['residual'] = df['prediction'] - df['petal_width']

px.scatter(
    df, x='prediction', y='residual',
    marginal_y='violin',
    color='split', trendline='ols'
)

# %% [markdown]
# ## KNN - Visualize Predictions

# %%
import plotly.express as px
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Load and split data
X, y = make_moons(noise=0.3, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(
    X, y.astype(str), test_size=0.25, random_state=0)

# Fit the model on training data, predict on test data
clf = KNeighborsClassifier(15)
clf.fit(X_train, y_train)
y_score = clf.predict_proba(X_test)[:, 1]

fig = px.scatter(
    X_test, x=0, y=1,
    color=y_score, color_continuous_scale='RdBu',
    symbol=y_test, symbol_map={'0': 'square-dot', '1': 'circle-dot'},
    labels={'symbol': 'label', 'color': 'score of <br>first class'}
)
fig.update_traces(marker_size=12, marker_line_width=1.5)
fig.update_layout(legend_orientation='h')
fig.show()
