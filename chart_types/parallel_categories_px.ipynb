# %% [markdown]
# # Parallel Categories With Plotly Express

# %%
import plotly.express as px

px.parallel_categories(px.data.tips())

# %% [markdown]
# ## Continuous Color

# %%
import plotly.express as px
px.parallel_categories(px.data.tips(), color="size", color_continuous_scale=px.colors.sequential.Inferno)
