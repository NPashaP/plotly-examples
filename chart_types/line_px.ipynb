# %% [markdown]
# # Line Plot with Express

# %% [markdown]
# ## Basic Example From List Data

# %%
import plotly.express as px
px.line(x=[1, 3, 2, 4], y=[1, 2, 3, 4])

# %% [markdown]
# ## Categorical Axis

# %%
import plotly.express as px
px.line(x=["a","b","c"], y=[1,3,2])

# %% [markdown]
# ## From DataFrame

# %%
import plotly.express as px
px.line(px.data.gapminder().query("continent=='Oceania'"), x="year", y="lifeExp")

# %% [markdown]
# ## Color

# %%
import plotly.express as px
px.line(px.data.gapminder().query("continent=='Oceania'"), x="year", y="lifeExp", color='country')

# %% [markdown]
# ## Markers

# %%
import plotly.express as px
px.line(px.data.gapminder().query("continent=='Oceania'"), x="year", y="lifeExp", color='country', markers=True)

# %% [markdown]
# ## Symbol

# %%
import plotly.express as px
px.line(px.data.gapminder().query("continent=='Oceania'"), x="year", y="lifeExp", color='country', symbol="country")

# %% [markdown]
# ## Label Points

# %%
import plotly.express as px

df = px.data.gapminder().query("country in ['Canada', 'Botswana']")

fig = px.line(df, x="lifeExp", y="gdpPercap", color="country", text="year")
fig.update_traces(textposition="bottom right")
fig

# %% [markdown]
# ## Spline and SVG Render

# %%
import plotly.express as px
px.line(px.data.gapminder(), x="year", y="lifeExp", color="continent", line_group="country", hover_name="country",
        line_shape="spline", render_mode="svg")

# %% [markdown]
# ## Facets

# %%
import plotly.express as px

fig = px.line(px.data.stocks(indexed=True), facet_row="company", facet_row_spacing=0.01, height=600, width=600)

# hide and lock down axes
fig.update_xaxes(visible=False, fixedrange=True)
fig.update_yaxes(visible=False, fixedrange=True)

# remove facet/subplot labels
fig.update_layout(annotations=[], overwrite=True)

# strip down the rest of the plot
fig.update_layout(
    showlegend=False,
    plot_bgcolor="white",
    margin={"t":10,"l":10,"b":10,"r":10}
)

# disable the modebar for such a small plot
fig.show(config={"displayModeBar":False})

# %%
import plotly.express as px

df = px.data.stocks()
px.line(df,  x="date", y=df.columns,
              hover_data={"date": "|%B %d, %Y"},
              title='custom tick labels')

# %%
import plotly.express as px

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = px.line(df, x='Date', y='AAPL.High', range_x=['2016-07-01','2016-12-31'])
fig.show()

# %% [markdown]
# ## Range Slider

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = px.line(df, x='Date', y='AAPL.High', title='Time Series with Rangeslider')

fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# ## Time Series with Range Selector Buttons

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

fig = px.line(df, x='Date', y='AAPL.High', title='Time Series with Range Slider and Selectors')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
